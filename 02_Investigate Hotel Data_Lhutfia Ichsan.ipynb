# %% [markdown]
# # Investigate Business Hotel Using Data Visualization

# %%
#Library 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 

# To Display Output without max columns 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#Define Dataset 
df = pd.read_csv('/content/drive/MyDrive/Gcollab /hotel_bookings_data.csv', delimiter=',')

# %%
# developer-friendly columns name 
df.columns = [x.lower().replace(' ', '_').replace('-', '_') for x in df.columns.to_list()]

df.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 27404   Resort Hotel            0         97               2019
# 13560   Resort Hotel            1        220               2019
# 43372     City Hotel            0         74               2017
# 112901    City Hotel            0        201               2019
# 35818   Resort Hotel            0         38               2019
#
#        arrival_date_month  arrival_date_week_number  \
# 27404             October                        32
# 13560             October                        33
# 43372            November                        38
# 112901               July                        21
# 35818                July                        18
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 27404                           8                        2
# 13560                          19                        4
# 43372                          18                        0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Descriptive

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_weekdays_nights               0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# city                                 488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# ...

# %%
df['company'].nunique_values()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
